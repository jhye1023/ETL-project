# %%
# %matplotlib notebook
import pandas as pd
import numpy as np
from datetime import date
import matplotlib.pyplot as plt
from sqlalchemy import create_engine
import psycopg2

# %%
engine = create_engine('postgresql://postgres:1023@localhost:5432/gun_violence')
conn = engine.connect()

# %%
gun_violence = pd.read_sql("SELECT * FROM gun_violance", conn)
gun_violence.sort_values('Total_Killed', ascending=False)
# Out:
#              State  Children_Killed  Teen_Killed  Acci_Child_Killed  \
# 18           Texas               35           22                 12
# 3       California               23           21                  1
# 15    Pennsylvania               19           14                  2
# 4          Florida               18           14                  2
# 6         Illinois               10           17                  1
# 11        Missouri               16            8                  4
# 16  South Carolina               15            6                  7
# 12  North Carolina               13            8                  1
# 14        Oklahoma               18            1                  2
# 5          Georgia               11            7                  3
# 13            Ohio                8           10                  4
# 0          Alabama               16            1                  7
# 17       Tennessee               11            6                  5
# ...

# %%
x_axis = np.arange(len(final))
tick_locations = [value for value in x_axis]

# %%
plt.figure(figsize=(10,3))
plt.bar(x_axis, final["Total_Killed"], color='r', alpha=0.5, align="center")
plt.xticks(tick_locations, final["State"], rotation=60)
plt.title("Total Underage Killed by Gun in 2019")
plt.ylabel("Number")
plt.xlabel("State")
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
plt.savefig("avg_state_rain.png")
